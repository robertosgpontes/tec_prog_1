# %% [markdown]
# <a href="https://colab.research.google.com/github/robertosgpontes/tec_prog_1/blob/main/Turma_922_Aula_6_(alunos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Documentação completa do Pandas: https://pandas.pydata.org/docs/reference/frame.html

# %% [markdown]
# Mount do Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Leitura do DataFrame

# %%
import pandas as pd
from IPython.display import display, HTML

df = pd.read_csv('/content/sample_data/sales.csv')

display(HTML(df.to_html()))
#print(df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Invoice ID</th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>Gender</th>
#       <th>Location</th>
#       <th>City</th>
#       <th>Member</th>
#       <th>Category</th>
#       <th>Price</th>
#       <th>Quantity</th>
#       <th>Total</th>
#       <th>Payment</th>
#       <th>Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>460489604</td>
#       <td>1/25/2018</td>
#       <td>16:46</td>
#       <td>Male</td>
#       <td>Brookfield</td>
#       <td>NewYork</td>
#       <td>Yes</td>
#       <td>Groceries</td>
#       <td>30</td>
#       <td>1</td>
#       <td>30</td>
#       <td>Cash</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>471006167</td>
#       <td>3/19/2018</td>
#       <td>16:48</td>
#       <td>Female</td>
#       <td>Water tower</td>
#       <td>Chicago</td>
# ...

# %% [markdown]
# Linhas e colunas

# %%
df.shape
# Out:
# (1000, 13)

# %% [markdown]
# DataTypes do DataFrame

# %%
df.dtypes
# Out:
# Invoice ID     int64
# Date          object
# Time          object
# Gender        object
# Location      object
# City          object
# Member        object
# Category      object
# Price          int64
# Quantity       int64
# Total          int64
# Payment       object
# Rating         int64
# dtype: object

# %% [markdown]
# Informações do DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Invoice ID  1000 non-null   int64
#  1   Date        1000 non-null   object
#  2   Time        1000 non-null   object
#  3   Gender      1000 non-null   object
#  4   Location    1000 non-null   object
#  5   City        1000 non-null   object
#  6   Member      1000 non-null   object
#  7   Category    1000 non-null   object
#  8   Price       1000 non-null   int64
#  9   Quantity    1000 non-null   int64
#  10  Total       1000 non-null   int64
#  11  Payment     1000 non-null   object
#  12  Rating      1000 non-null   int64
# dtypes: int64(5), object(8)
# memory usage: 101.7+ KB

# %% [markdown]
# Descritivo do DataFrame

# %%
df.describe()
# Out:
#          Invoice ID        Price     Quantity        Total       Rating
# count  1.000000e+03  1000.000000  1000.000000  1000.000000  1000.000000
# mean   4.944931e+08    51.112000     4.059000   207.788000     2.972000
# std    2.870685e+08    28.912443     2.027716   165.626167     1.428025
# min    6.614050e+05     1.000000     1.000000     1.000000     1.000000
# 25%    2.508726e+08    27.000000     2.000000    72.000000     2.000000
# 50%    4.781491e+08    51.000000     4.000000   174.000000     3.000000
# 75%    7.459453e+08    76.250000     6.000000   304.500000     4.000000
# max    9.996658e+08   100.000000     7.000000   693.000000     5.000000

# %% [markdown]
# Verifica se tem NaN (Not a Number)

# %%
df.isna()
# Out:
#      Invoice ID   Date   Time  Gender  Location   City  Member  Category  \
# 0         False  False  False   False     False  False   False     False
# 1         False  False  False   False     False  False   False     False
# 2         False  False  False   False     False  False   False     False
# 3         False  False  False   False     False  False   False     False
# 4         False  False  False   False     False  False   False     False
# ..          ...    ...    ...     ...       ...    ...     ...       ...
# 995       False  False  False   False     False  False   False     False
# 996       False  False  False   False     False  False   False     False
# 997       False  False  False   False     False  False   False     False
# 998       False  False  False   False     False  False   False     False
# 999       False  False  False   False     False  False   False     False
#
#      Price  Quantity  Total  Payment  Rating
# 0    False     False  False    False   False
# ...

# %% [markdown]
# Verifica se tem NULL

# %%
df.isnull()
# Out:
#      Invoice ID   Date   Time  Gender  Location   City  Member  Category  \
# 0         False  False  False   False     False  False   False     False
# 1         False  False  False   False     False  False   False     False
# 2         False  False  False   False     False  False   False     False
# 3         False  False  False   False     False  False   False     False
# 4         False  False  False   False     False  False   False     False
# ..          ...    ...    ...     ...       ...    ...     ...       ...
# 995       False  False  False   False     False  False   False     False
# 996       False  False  False   False     False  False   False     False
# 997       False  False  False   False     False  False   False     False
# 998       False  False  False   False     False  False   False     False
# 999       False  False  False   False     False  False   False     False
#
#      Price  Quantity  Total  Payment  Rating
# 0    False     False  False    False   False
# ...

# %% [markdown]
# Verifica se NÃO tem NaN (Not a Number)

# %%
df.notna()
# Out:
#      Invoice ID  Date  Time  Gender  Location  City  Member  Category  Price  \
# 0          True  True  True    True      True  True    True      True   True
# 1          True  True  True    True      True  True    True      True   True
# 2          True  True  True    True      True  True    True      True   True
# 3          True  True  True    True      True  True    True      True   True
# 4          True  True  True    True      True  True    True      True   True
# ..          ...   ...   ...     ...       ...   ...     ...       ...    ...
# 995        True  True  True    True      True  True    True      True   True
# 996        True  True  True    True      True  True    True      True   True
# 997        True  True  True    True      True  True    True      True   True
# 998        True  True  True    True      True  True    True      True   True
# 999        True  True  True    True      True  True    True      True   True
#
#      Quantity  Total  Payment  Rating
# ...

# %% [markdown]
# Verificad se NÃO tem NULL

# %%
pd.set_option('display.max_rows', 1000)
df.notnull()
# Out:
#      Invoice ID  Date  Time  Gender  Location  City  Member  Category  Price  \
# 0          True  True  True    True      True  True    True      True   True
# 1          True  True  True    True      True  True    True      True   True
# 2          True  True  True    True      True  True    True      True   True
# 3          True  True  True    True      True  True    True      True   True
# 4          True  True  True    True      True  True    True      True   True
# 5          True  True  True    True      True  True    True      True   True
# 6          True  True  True    True      True  True    True      True   True
# 7          True  True  True    True      True  True    True      True   True
# 8          True  True  True    True      True  True    True      True   True
# 9          True  True  True    True      True  True    True      True   True
# 10         True  True  True    True      True  True    True      True   True
# ...

# %% [markdown]
# Verifica se tem duplicados

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
pd.set_option('display.max_rows', 1000)
print(df)
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8     325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 11    846531724  3/15/2018  12:12    Male    Park lane   Dallas     No
# ...

# %% [markdown]
# Excluir colunas

# %%
df.drop(columns=['Payment', 'Total'])
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8     325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 11    846531724  3/15/2018  12:12    Male    Park lane   Dallas     No
# ...

# %% [markdown]
# Excluir registros NaN (Not a Number)

# %%
df.dropna()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8     325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 11    846531724  3/15/2018  12:12    Male    Park lane   Dallas     No
# ...

# %% [markdown]
# Insere uma linha no DataFrame a partir de uma lista

# %%
lista = [None, None, None, None, None, None, None, None, None, None, None, None, None]
df.loc[len(df)] = lista

# %%
print(df)
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ...         ...        ...    ...     ...          ...      ...    ...
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
# 1000       None       None   None    None         None     None   None
# 1001       None       None   None    None         None     None   None
#
#        Category Price Quantity Total Payment Rating
# 0     Groceries    30        1    30    Cash      2
# ...

# %%
df.dropna()
# Out:
#       Invoice ID       Date   Time  Gender     Location     City Member  \
# 0    460489604.0  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1    471006167.0  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2    411909258.0  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3    487313402.0  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4    197763430.0  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5    263634050.0   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6     99646662.0   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7    188869875.0   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8    325637547.0  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9    562942936.0  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668.0  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 11   846531724.0  3/15/2018  12:12    Male    Park lane   Dallas     No
# ...

# %% [markdown]
# Exclui duplicados

# %%
df.drop_duplicates()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ...         ...        ...    ...     ...          ...      ...    ...
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
# 1000       None       None   None    None         None     None   None
#
#        Category Price Quantity Total Payment Rating
# 0     Groceries    30        1    30    Cash      2
# ...

# %% [markdown]
# Converte uma coluna em uma lista

# %%
df['Invoice ID'].tolist()
# Out:
# [460489604,
#  471006167,
#  411909258,
#  487313402,
#  197763430,
#  263634050,
#  99646662,
#  188869875,
#  325637547,
#  562942936,
#  388412668,
#  846531724,
#  149894432,
#  942406749,
#  547572603,
#  355981315,
#  397754805,
#  90524319,
#  542144906,
#  729486362,
#  619639105,
#  443198801,
#  761515143,
#  56578535,
#  834838148,
#  833288071,
#  508614950,
#  103072863,
#  355815500,
#  193855414,
#  600792216,
#  567867755,
#  597934753,
#  419033295,
#  8795029,
#  912473338,
#  209725428,
#  460044751,
#  191736512,
#  979973145,
#  43371182,
#  613811022,
#  673603546,
#  328132417,
#  325924536,
#  747705702,
#  450817216,
#  315624039,
#  888822600,
#  896399395,
#  20548577,
#  500850764,
#  466598448,
#  265371038,
#  175938157,
#  839600262,
#  885253494,
#  180545139,
#  227063423,
#  500777576,
#  426576006,
#  934647292,
#  975443414,
#  858716993,
#  776761484,
#  798252244,
#  595065138,
#  366083315,
#  746011173,
#  687132774,
#  554361739,
# ...

# %% [markdown]
# Group By com Pandas

# %%
df.groupby(['City'])['City'].count()
# Out:
# City
# Chicago    328
# Dallas     332
# NewYork    340
# Name: City, dtype: int64

# %% [markdown]
# Group By com PandaSQL

# %%
from pandasql import PandaSQL
pdsql = PandaSQL()
query = "SELECT COUNT(City), City FROM df GROUP BY City"
df_final = pdsql(query)
print(df_final)
# Out:
#    COUNT(City)     City
# 0          328  Chicago
# 1          332   Dallas
# 2          340  NewYork
